# %% [markdown]
# # 1. ABOUT DATA

# %% [markdown]
# **Data**:  Apple AppStore Dataset
#
# The dataset was collected from Kaggle [Uploaded by GAUTHAM PRAKASH]

# %% [markdown]
# # 2. TASK

# %% [markdown]
# We're going to explore the dataset to understand it better through Exploratory Data Analysis (EDA). This exploration will help us identify what needs to be cleaned and normalized in the data. As we write the code, we'll take notes on what we discover. Finally, we'll summarize our findings and draw conclusions from the analysis.

# %% [markdown]
# # 3. OBJECTIVES

# %% [markdown]
# The main goal of this project is to carefully analyze the dataset to discover important insights. The ultimate aim is to highlight customer behaviors and preferences to developers and other stakeholders. This information will help attract more business for their upcoming applications.

# %% [markdown]
# # 4. LIBRARIES USED

# %% [markdown]
# 1. Pandas: Data manipulation and analysis library.
# 2. Numpy: Numerical computing library.
# 3. Matplotlib: Data visualization library.
# 4. Seaborn: Statistical data visualization library.
# 5. Scipy: To provide a comprehensive set of numerical algorithms and tools for scientific computing in Python.

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

import scipy as s

# %% [markdown]
# # 5. Data Loading, Exploration & Wrangling

# %% [markdown]
# ## 5.1.  Load the csv file with the help of pandas library
#
#
#       The dataset is collected from Kaggle due to its large dataset we need to
#       use parameters like **encoding='latin1'** and **error_bad_lines=False**
#       to handle encoding issues and skip lines with errors, respectively.
#
#
# ## 5.2.  Creating the dataframe and understanding the data present in the dataset

# %%
chunk_size = 10000

chunks = pd.read_csv('/content/appleAppData.csv', encoding='latin1', error_bad_lines=False, chunksize=chunk_size)

df = pd.concat(chunks, ignore_index=True)
# Out:
# <ipython-input-2-c997fe885826>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chunks = pd.read_csv('/content/appleAppData.csv', encoding='latin1', error_bad_lines=False, chunksize=chunk_size)
# Skipping line 9480: expected 21 fields, saw 28
#
# Skipping line 18952: expected 21 fields, saw 29
#
# Skipping line 28440: expected 21 fields, saw 29
#
# Skipping line 34767: expected 21 fields, saw 23
#
# Skipping line 41139: expected 21 fields, saw 27
# Skipping line 44310: expected 21 fields, saw 27
# Skipping line 47467: expected 21 fields, saw 22
#
# Skipping line 50654: expected 21 fields, saw 22
# Skipping line 57039: expected 21 fields, saw 24
#
# Skipping line 60210: expected 21 fields, saw 30
# Skipping line 66589: expected 21 fields, saw 28
#
# Skipping line 72987: expected 21 fields, saw 23
# Skipping line 79367: expected 21 fields, saw 28
#
# Skipping line 95334: expected 21 fields, saw 35
#
# Skipping line 108112: expected 21 fields, saw 34
#
# Skipping line 117678: expected 21 fields, saw 27
#
# Skipping line 124006: expected 21 fields, saw 36
#
# Skipping line 133505: expected 21 fields, saw 36

# %% [markdown]
# ## 5.3. **Get a sneak peek of your data** **bold text** **bold text**

# %%
df
# Out:
#                                   App_Id                 App_Name  \
# 0                    com.hkbu.arc.apaper           A+ Paper Guide
# 1                    com.dmitriev.abooks                  A-Books
# 2                         no.terp.abooks                  A-books
# 3               fr.antoinettefleur.Book1              A-F Book #1
# 4       com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
# ...                                  ...                      ...
# 136628                com.mbos.joindrebo       Joindre Backoffice
# 136629         com.superevent.joiningias              Joining IAS
# 136630               com.joinin.Entronix                  Join-In
# 136631    com.streams.rental.joinme.user             JoinMeæªè»
# 136632                           ch.join                      NaN
#
#                                              AppStore_Url Primary_Genre  \
# 0       https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1       https://apps.apple.com/us/app/a-books/id103157...          Book
# 2       https://apps.apple.com/us/app/a-books/id145702...          Book
# 3       https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4       https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
# ...                                                   ...           ...
# 136628  https://apps.apple.com/us/app/joindre-backoffi...       Finance
# 136629  https://apps.apple.com/us/app/joining-ias/id13...     Reference
# 136630  https://apps.apple.com/us/app/join-in/id109225...  Productivity
# 136631  https://apps.apple.com/us/app/joinme%E6%8F%AA%...      Business
# 136632                                                NaN           NaN
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0                  4+    21993472                  8.0  2017-09-28T03:02:41Z
# 1                  4+    13135872                 10.0  2015-08-31T19:31:32Z
# 2                  4+    21943296                  9.0  2021-04-14T07:00:00Z
# 3                  4+    81851392                  8.0  2012-02-10T03:40:07Z
# 4                  4+    64692224                  9.0  2020-12-16T08:00:00Z
# ...               ...         ...                  ...                   ...
# 136628             4+  74100736.0                 11.2  2021-03-24T07:00:00Z
# 136629             4+  24165376.0                  9.0  2017-10-24T21:08:07Z
# 136630             4+   5932032.0                  8.0  2016-04-28T15:36:03Z
# 136631             4+  58025984.0                 11.0  2021-07-22T07:00:00Z
# 136632            NaN         NaN                  NaN                   NaN
#
#                      Updated Version  ... Currency   Free   DeveloperId  \
# 0       2018-12-21T21:30:36Z   1.1.2  ...      USD   True    1375410542
# 1       2019-07-23T20:31:09Z     1.3  ...      USD   True    1031572001
# 2       2021-05-30T21:08:54Z   1.3.1  ...      USD   True    1457024163
# 3       2019-10-29T12:40:37Z     1.2  ...      USD  False     439568839
# 4       2020-12-18T21:36:11Z   1.0.1  ...      USD   True     656731821
# ...                      ...     ...  ...      ...    ...           ...
# 136628  2021-08-16T12:36:38Z   1.9.3  ...      USD   True  1553727169.0
# 136629  2017-10-24T21:08:07Z  3.39.1  ...      USD   True   588706763.0
# 136630  2016-08-24T23:17:18Z  1.0.49  ...      USD   True  1092254159.0
# 136631  2021-09-15T02:04:01Z     1.1  ...      USD   True   386268761.0
# 136632                   NaN     NaN  ...      NaN    NaN           NaN
#
#                                  Developer  \
# 0                                 HKBU ARC
# 1                           Roman Dmitriev
# 2                                  Terp AS
# 3                            i-editeur.com
# 4                            Ngov chiheang
# ...                                    ...
# 136628  Joindre Capital Services Pvt. Ltd.
# 136629                     Superevent B.V.
# 136630                        Entronix LLC
# 136631          Streams System Corporation
# 136632                                 NaN
#
#                                             Developer_Url  \
# 0       https://apps.apple.com/us/developer/hkbu-arc/i...
# 1       https://apps.apple.com/us/developer/roman-dmit...
# 2       https://apps.apple.com/us/developer/terp-as/id...
# 3       https://apps.apple.com/us/developer/i-editeur-...
# 4       https://apps.apple.com/us/developer/ngov-chihe...
# ...                                                   ...
# 136628  https://apps.apple.com/us/developer/joindre-ca...
# 136629  https://apps.apple.com/us/developer/superevent...
# 136630  https://apps.apple.com/us/developer/entronix-l...
# 136631  https://apps.apple.com/us/developer/streams-sy...
# 136632                                                NaN
#
#                Developer_Website Average_User_Rating  Reviews  \
# 0                            NaN                 0.0      0.0
# 1                            NaN                 5.0      1.0
# 2                            NaN                 0.0      0.0
# 3                            NaN                 0.0      0.0
# 4        http://imonstersoft.com                 0.0      0.0
# ...                          ...                 ...      ...
# 136628  https://www.joindre.com/                 4.0      2.0
# 136629                       NaN                 0.0      0.0
# 136630                       NaN                 0.0      0.0
# 136631                       NaN                 0.0      0.0
# 136632                       NaN                 NaN      NaN
#
#         Current_Version_Score  Current_Version_Reviews
# 0                         0.0                      0.0
# 1                         5.0                      1.0
# 2                         0.0                      0.0
# 3                         0.0                      0.0
# 4                         0.0                      0.0
# ...                       ...                      ...
# 136628                    4.0                      2.0
# 136629                    0.0                      0.0
# 136630                    0.0                      0.0
# 136631                    0.0                      0.0
# 136632                    NaN                      NaN
#
# [136633 rows x 21 columns]

# %% [markdown]
# ## 5.4. View the shape of the dataset

# %%
print(f"The dataframe has {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# The dataframe has 136633 rows and 21 columns

# %% [markdown]
# ## 5.5. View the column names

# %%
print(df.columns.values)
# Out:
# ['App_Id' 'App_Name' 'AppStore_Url' 'Primary_Genre' 'Content_Rating'
#  'Size_Bytes' 'Required_IOS_Version' 'Released' 'Updated' 'Version'
#  'Price' 'Currency' 'Free' 'DeveloperId' 'Developer' 'Developer_Url'
#  'Developer_Website' 'Average_User_Rating' 'Reviews'
#  'Current_Version_Score' 'Current_Version_Reviews']

# %% [markdown]
# ## 5.6. Display all columns when outputting DataFrames

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating Size_Bytes Required_IOS_Version              Released  \
# 0             4+   21993472                  8.0  2017-09-28T03:02:41Z
# 1             4+   13135872                 10.0  2015-08-31T19:31:32Z
# 2             4+   21943296                  9.0  2021-04-14T07:00:00Z
# 3             4+   81851392                  8.0  2012-02-10T03:40:07Z
# 4             4+   64692224                  9.0  2020-12-16T08:00:00Z
#
#                 Updated Version Price Currency   Free DeveloperId  \
# 0  2018-12-21T21:30:36Z   1.1.2   0.0      USD   True  1375410542
# 1  2019-07-23T20:31:09Z     1.3   0.0      USD   True  1031572001
# 2  2021-05-30T21:08:54Z   1.3.1   0.0      USD   True  1457024163
# 3  2019-10-29T12:40:37Z     1.2  2.99      USD  False   439568839
# 4  2020-12-18T21:36:11Z   1.0.1   0.0      USD   True   656731821
#
#         Developer                                      Developer_Url  \
# 0        HKBU ARC  https://apps.apple.com/us/developer/hkbu-arc/i...
# 1  Roman Dmitriev  https://apps.apple.com/us/developer/roman-dmit...
# 2         Terp AS  https://apps.apple.com/us/developer/terp-as/id...
# 3   i-editeur.com  https://apps.apple.com/us/developer/i-editeur-...
# 4   Ngov chiheang  https://apps.apple.com/us/developer/ngov-chihe...
#
#          Developer_Website  Average_User_Rating  Reviews  \
# 0                      NaN                  0.0      0.0
# 1                      NaN                  5.0      1.0
# 2                      NaN                  0.0      0.0
# 3                      NaN                  0.0      0.0
# 4  http://imonstersoft.com                  0.0      0.0
#
#    Current_Version_Score  Current_Version_Reviews
# 0                    0.0                      0.0
# 1                    5.0                      1.0
# 2                    0.0                      0.0
# 3                    0.0                      0.0
# 4                    0.0                      0.0

# %% [markdown]
# ## 5.7. Descriptive Statistics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136633 entries, 0 to 136632
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   App_Id                   136633 non-null  object
#  1   App_Name                 136632 non-null  object
#  2   AppStore_Url             136631 non-null  object
#  3   Primary_Genre            136631 non-null  object
#  4   Content_Rating           136632 non-null  object
#  5   Size_Bytes               136632 non-null  object
#  6   Required_IOS_Version     136630 non-null  object
#  7   Released                 136629 non-null  object
#  8   Updated                  136628 non-null  object
#  9   Version                  136627 non-null  object
#  10  Price                    136618 non-null  object
#  11  Currency                 136626 non-null  object
#  12  Free                     136626 non-null  object
#  13  DeveloperId              136624 non-null  object
#  14  Developer                136624 non-null  object
#  15  Developer_Url            136541 non-null  object
#  16  Developer_Website        69074 non-null   object
#  17  Average_User_Rating      136620 non-null  float64
#  18  Reviews                  136618 non-null  float64
#  19  Current_Version_Score    136618 non-null  float64
#  20  Current_Version_Reviews  136613 non-null  float64
# dtypes: float64(4), object(17)
# memory usage: 21.9+ MB

# %%
df.describe()
# Out:
#        Average_User_Rating       Reviews  Current_Version_Score  \
# count        136620.000000  1.366180e+05          136618.000000
# mean              1.562526  5.637945e+02               1.562549
# std               2.115964  3.806632e+04               2.115971
# min               0.000000  0.000000e+00               0.000000
# 25%               0.000000  0.000000e+00               0.000000
# 50%               0.000000  0.000000e+00               0.000000
# 75%               4.000000  2.000000e+00               4.000000
# max               5.000000  7.181127e+06               5.000000
#
#        Current_Version_Reviews
# count             1.366130e+05
# mean              5.638150e+02
# std               3.806701e+04
# min               0.000000e+00
# 25%               0.000000e+00
# 50%               0.000000e+00
# 75%               2.000000e+00
# max               7.181127e+06

# %% [markdown]
# # 6. Missing Values

# %% [markdown]
# ## 6.1 Check missing values in the data

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Developer_Website          67559
# Developer_Url                 92
# Current_Version_Reviews       20
# Current_Version_Score         15
# Reviews                       15
# Price                         15
# Average_User_Rating           13
# DeveloperId                    9
# Developer                      9
# Currency                       7
# Free                           7
# Version                        6
# Updated                        5
# Released                       4
# Required_IOS_Version           3
# Primary_Genre                  2
# AppStore_Url                   2
# App_Name                       1
# Size_Bytes                     1
# Content_Rating                 1
# App_Id                         0
# dtype: int64

# %% [markdown]
# ## 6.2 Percentage of null values in the dataset sorted in ascending order

# %%
missing_percentage = (df.isnull().sum().sort_values(ascending = False)/len(df))*100
missing_percentage
# Out:
# Developer_Website          49.445595
# Developer_Url               0.067334
# Current_Version_Reviews     0.014638
# Current_Version_Score       0.010978
# Reviews                     0.010978
# Price                       0.010978
# Average_User_Rating         0.009515
# DeveloperId                 0.006587
# Developer                   0.006587
# Currency                    0.005123
# Free                        0.005123
# Version                     0.004391
# Updated                     0.003659
# Released                    0.002928
# Required_IOS_Version        0.002196
# Primary_Genre               0.001464
# AppStore_Url                0.001464
# App_Name                    0.000732
# Size_Bytes                  0.000732
# Content_Rating              0.000732
# App_Id                      0.000000
# dtype: float64

# %% [markdown]
# ## 6.3 Exploratory Analysis

# %% [markdown]
# ### Provide us the visual on the missing values in a dataframe 'df'

# %%
plt.rcParams['figure.figsize'] = (15,6)
sns.heatmap(df.isnull(),yticklabels = False, cbar = False , cmap = 'viridis')
plt.title("Missing null values")
# Out:
# Text(0.5, 1.0, 'Missing null values')

# %% [markdown]
# ### Graphical representation of the percentage of null values

# %%
missing_percentage = missing_percentage[missing_percentage != 0] # Only the missing data
plt.rcParams['figure.figsize'] = (20,6)
missing_percentage.plot(kind = 'barh')
plt.title("Percentage of null values")
# Out:
# Text(0.5, 1.0, 'Percentage of null values')

# %% [markdown]
# ## 6.4 Dealing with the null values

# %% [markdown]
# ### Drop Developer Website

# %% [markdown]
# We decided to remove the "Developer Website" information from the dataset because it wasn't relevant to our analysis, and there were many missing (NULL) values associated with it.

# %%
df.drop('Developer_Website', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136633 entries, 0 to 136632
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   App_Id                   136633 non-null  object
#  1   App_Name                 136632 non-null  object
#  2   AppStore_Url             136631 non-null  object
#  3   Primary_Genre            136631 non-null  object
#  4   Content_Rating           136632 non-null  object
#  5   Size_Bytes               136632 non-null  object
#  6   Required_IOS_Version     136630 non-null  object
#  7   Released                 136629 non-null  object
#  8   Updated                  136628 non-null  object
#  9   Version                  136627 non-null  object
#  10  Price                    136618 non-null  object
#  11  Currency                 136626 non-null  object
#  12  Free                     136626 non-null  object
#  13  DeveloperId              136624 non-null  object
#  14  Developer                136624 non-null  object
#  15  Developer_Url            136541 non-null  object
#  16  Average_User_Rating      136620 non-null  float64
#  17  Reviews                  136618 non-null  float64
#  18  Current_Version_Score    136618 non-null  float64
#  19  Current_Version_Reviews  136613 non-null  float64
# dtypes: float64(4), object(16)
# memory usage: 20.8+ MB

# %% [markdown]
# ### Filling the Null Values

# %%
# Convert 'Price' column to numeric values
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# Fill NaN values with the mean
df['Price'] = df['Price'].fillna(value=df['Price'].mean())
df['Size_Bytes'] = df['Size_Bytes'].fillna(value=df['Size_Bytes'].mean())

# %% [markdown]
# ### Have a view of refreshed dataset again

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Developer_Url              92
# Current_Version_Reviews    20
# Current_Version_Score      15
# Reviews                    15
# Average_User_Rating        13
# DeveloperId                 9
# Developer                   9
# Currency                    7
# Free                        7
# Version                     6
# Updated                     5
# Released                    4
# Required_IOS_Version        3
# Primary_Genre               2
# AppStore_Url                2
# Content_Rating              1
# App_Name                    1
# App_Id                      0
# Size_Bytes                  0
# Price                       0
# dtype: int64

# %% [markdown]
# ### View those rows where a column has null values

# %%
df[df['Current_Version_Reviews'].isnull()].head()
# Out:
#                         App_Id  \
# 15779     com.habn.giaibaitap7
# 22113         com.pacfast.user
# 25291      ru.ctm.rail-locator
# 31592  com.gogolec.EasyTodoBig
# 37955                    maxit
#
#                                                 App_Name  \
# 15779                        Giáº£i BÃ i Táº­p 7 Offline
# 22113                                          PACFASTPH
# 25291                                Rail-ÐÐ¾ÐºÐ°ÑÐ¾Ñ
# 31592                                      Easy Todo Big
# 37955  Ability mLearning Plhttp://bibleall.com/Bhagav...
#
#                                             AppStore_Url Primary_Genre  \
# 15779  https://apps.apple.com/us/app/gi%E1%BA%A3i-b%C...     Education
# 22113  https://apps.apple.com/us/app/pacfastph/id1547...      Business
# 25291  https://apps.apple.com/us/app/rail-%D0%BB%D0%B...      Business
# 31592  https://apps.apple.com/us/app/easy-todo-big/id...      Business
# 37955                                                0.0             0
#
#       Content_Rating   Size_Bytes Required_IOS_Version              Released  \
# 15779             4+   78074880.0                  9.0  2018-08-19T00:10:16Z
# 22113             4+   47874048.0                 12.2  2021-02-26T08:00:00Z
# 25291             4+  105987072.0                 11.0              2019-04-
# 31592             4+    3624960.0                  7.0  2015-11-17T22:05:24Z
# 37955            0.0          0.0                  NaN                   NaN
#
#                                                  Updated  \
# 15779  2018-08tps://apps.apple.com/us/developer/janes...
# 22113  2021-09-29T23:06:42Zhttp://bibleall.com/Bhagav...
# 25291                                              3.3.1
# 31592                               2015-11-17T22:05:24Z
# 37955                                                NaN
#
#                      Version         Price Currency        Free  \
# 15779  https://www.janes.com      3.333330        3     3.33333
# 22113                    0.0      0.000000      0.0           0
# 25291                    0.0  10783.590774     True  1542212738
# 31592                  1.0.0      0.000000      USD        True
# 37955                    NaN  10783.590774      NaN         NaN
#
#                                  DeveloperId  \
# 15779                                      3
# 22113                                    NaN
# 25291  PACIFIC CARGO SERVICES & TRADING CORP
# 31592                            621837478.0
# 37955                                    NaN
#
#                                                Developer  \
# 15779                                                NaN
# 22113                                                NaN
# 25291  https://apps.apple.com/us/developer/pacific-ca...
# 31592  hirofumi yamtps://apps.apple.com/us/developer/...
# 37955                                                NaN
#
#                Developer_Url  Average_User_Rating  Reviews  \
# 15779                    NaN                  NaN      NaN
# 22113                    NaN                  NaN      NaN
# 25291                    NaN                  0.0  0.00000
# 31592  https://www.janes.com                  3.0  3.33333
# 37955                    NaN                  NaN      NaN
#
#        Current_Version_Score  Current_Version_Reviews
# 15779                    NaN                      NaN
# 22113                    NaN                      NaN
# 25291                    0.0                      NaN
# 31592                    3.0                      NaN
# 37955                    NaN                      NaN

# %%
df[df['Reviews'].isnull()].head()
# Out:
#                           App_Id  \
# 15779       com.habn.giaibaitap7
# 22113           com.pacfast.user
# 37955                      maxit
# 53838                      maxit
# 63390  events.camarote.organizer
#
#                                                 App_Name  \
# 15779                        Giáº£i BÃ i Táº­p 7 Offline
# 22113                                          PACFASTPH
# 37955  Ability mLearning Plhttp://bibleall.com/Bhagav...
# 53838  Ability mLearning Plus/developer/oil-gas-uk/id...
# 63390                             Camarote - Organizador
#
#                                             AppStore_Url Primary_Genre  \
# 15779  https://apps.apple.com/us/app/gi%E1%BA%A3i-b%C...     Education
# 22113  https://apps.apple.com/us/app/pacfastph/id1547...      Business
# 37955                                                0.0             0
# 53838                                                NaN           0.0
# 63390  https://apps.apple.com/us/app/camarote-organiz...      Business
#
#       Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 15779             4+  78074880.0                  9.0  2018-08-19T00:10:16Z
# 22113             4+  47874048.0                 12.2  2021-02-26T08:00:00Z
# 37955            0.0         0.0                  NaN                   NaN
# 53838              0         0.0                    0                   NaN
# 63390             4+  81971200.0                  9.0  2018-07-10T17:12:05Z
#
#                                                  Updated  \
# 15779  2018-08tps://apps.apple.com/us/developer/janes...
# 22113  2021-09-29T23:06:42Zhttp://bibleall.com/Bhagav...
# 37955                                                NaN
# 53838                                                NaN
# 63390                                             201872
#
#                      Version         Price Currency     Free DeveloperId  \
# 15779  https://www.janes.com      3.333330        3  3.33333           3
# 22113                    0.0      0.000000      0.0        0         NaN
# 37955                    NaN  10783.590774      NaN      NaN         NaN
# 53838                    NaN  10783.590774      NaN      NaN         NaN
# 63390              qinmin xu  10783.590774      NaN      0.0         0.0
#
#       Developer Developer_Url  Average_User_Rating  Reviews  \
# 15779       NaN           NaN                  NaN      NaN
# 22113       NaN           NaN                  NaN      NaN
# 37955       NaN           NaN                  NaN      NaN
# 53838       NaN           NaN                  NaN      NaN
# 63390       0.0             0                  NaN      NaN
#
#        Current_Version_Score  Current_Version_Reviews
# 15779                    NaN                      NaN
# 22113                    NaN                      NaN
# 37955                    NaN                      NaN
# 53838                    NaN                      NaN
# 63390                    NaN                      NaN

# %%
df[df['Developer'].isnull()].head()
# Out:
#                      App_Id  \
# 15779  com.habn.giaibaitap7
# 22113      com.pacfast.user
# 37955                 maxit
# 53838                 maxit
# 69783   com.fideoo.legarden
#
#                                                 App_Name  \
# 15779                        Giáº£i BÃ i Táº­p 7 Offline
# 22113                                          PACFASTPH
# 37955  Ability mLearning Plhttp://bibleall.com/Bhagav...
# 53838  Ability mLearning Plus/developer/oil-gas-uk/id...
# 69783                                          Le Garden
#
#                                             AppStore_Url Primary_Genre  \
# 15779  https://apps.apple.com/us/app/gi%E1%BA%A3i-b%C...     Education
# 22113  https://apps.apple.com/us/app/pacfastph/id1547...      Business
# 37955                                                0.0             0
# 53838                                                NaN           0.0
# 69783  https://apps.apple.com/us/app/le-us/developer/...           NaN
#
#       Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 15779             4+  78074880.0                  9.0  2018-08-19T00:10:16Z
# 22113             4+  47874048.0                 12.2  2021-02-26T08:00:00Z
# 37955            0.0         0.0                  NaN                   NaN
# 53838              0         0.0                    0                   NaN
# 69783            0.0         0.0                  0.0                     0
#
#                                                  Updated  \
# 15779  2018-08tps://apps.apple.com/us/developer/janes...
# 22113  2021-09-29T23:06:42Zhttp://bibleall.com/Bhagav...
# 37955                                                NaN
# 53838                                                NaN
# 69783                                                NaN
#
#                      Version         Price Currency     Free DeveloperId  \
# 15779  https://www.janes.com      3.333330        3  3.33333           3
# 22113                    0.0      0.000000      0.0        0         NaN
# 37955                    NaN  10783.590774      NaN      NaN         NaN
# 53838                    NaN  10783.590774      NaN      NaN         NaN
# 69783                    NaN  10783.590774      NaN      NaN         NaN
#
#       Developer Developer_Url  Average_User_Rating  Reviews  \
# 15779       NaN           NaN                  NaN      NaN
# 22113       NaN           NaN                  NaN      NaN
# 37955       NaN           NaN                  NaN      NaN
# 53838       NaN           NaN                  NaN      NaN
# 69783       NaN           NaN                  NaN      NaN
#
#        Current_Version_Score  Current_Version_Reviews
# 15779                    NaN                      NaN
# 22113                    NaN                      NaN
# 37955                    NaN                      NaN
# 53838                    NaN                      NaN
# 69783                    NaN                      NaN

# %%
df[df['DeveloperId'].isnull()].head()
# Out:
#                                  App_Id  \
# 22113                  com.pacfast.user
# 37955                             maxit
# 53838                             maxit
# 69783               com.fideoo.legarden
# 76161  com.GonnelliDomenico.FirebaseApp
#
#                                                 App_Name  \
# 22113                                          PACFASTPH
# 37955  Ability mLearning Plhttp://bibleall.com/Bhagav...
# 53838  Ability mLearning Plus/developer/oil-gas-uk/id...
# 69783                                          Le Garden
# 76161                                              Fire+
#
#                                             AppStore_Url Primary_Genre  \
# 22113  https://apps.apple.com/us/app/pacfastph/id1547...      Business
# 37955                                                0.0             0
# 53838                                                NaN           0.0
# 69783  https://apps.apple.com/us/app/le-us/developer/...           NaN
# 76161                                           14008320           9.0
#
#              Content_Rating    Size_Bytes Required_IOS_Version  \
# 22113                    4+  4.787405e+07                 12.2
# 37955                   0.0  0.000000e+00                  NaN
# 53838                     0  0.000000e+00                    0
# 69783                   0.0  0.000000e+00                  0.0
# 76161  2019-07-24T07:00:00Z  6.842015e+07                4.1.0
#
#                    Released  \
# 22113  2021-02-26T08:00:00Z
# 37955                   NaN
# 53838                   NaN
# 69783                     0
# 76161                   0.0
#
#                                                  Updated Version  \
# 22113  2021-09-29T23:06:42Zhttp://bibleall.com/Bhagav...     0.0
# 37955                                                NaN     NaN
# 53838                                                NaN     NaN
# 69783                                                NaN     NaN
# 76161                                                USD    True
#
#               Price                          Currency  \
# 22113  0.000000e+00                               0.0
# 37955  1.078359e+04                               NaN
# 53838  1.078359e+04                               NaN
# 69783  1.078359e+04                               NaN
# 76161  1.473045e+09  JFL Total Wealth Management, LLC
#
#                                                     Free DeveloperId  \
# 22113                                                  0         NaN
# 37955                                                NaN         NaN
# 53838                                                NaN         NaN
# 69783                                                NaN         NaN
# 76161  https://apps.apple.com/us/developer/jfl-total-...         NaN
#
#       Developer Developer_Url  Average_User_Rating  Reviews  \
# 22113       NaN           NaN                  NaN      NaN
# 37955       NaN           NaN                  NaN      NaN
# 53838       NaN           NaN                  NaN      NaN
# 69783       NaN           NaN                  NaN      NaN
# 76161       0.0             0                  0.0      NaN
#
#        Current_Version_Score  Current_Version_Reviews
# 22113                    NaN                      NaN
# 37955                    NaN                      NaN
# 53838                    NaN                      NaN
# 69783                    NaN                      NaN
# 76161                    NaN                      NaN

# %%
df[df['Free'].isnull()].head()
# Out:
#                                                    App_Id  \
# 37955                                               maxit
# 53838                                               maxit
# 69783                                 com.fideoo.legarden
# 104915                               com.glive.JOBBKKFAIR
# 114452  com/us/developer/zoho-corporation/id388384807?...
#
#                                                  App_Name  \
# 37955   Ability mLearning Plhttp://bibleall.com/Bhagav...
# 53838   Ability mLearning Plus/developer/oil-gas-uk/id...
# 69783                                           Le Garden
# 104915                                        JOBBKK FAIR
# 114452                    https://www.zoho.com/bugtracker
#
#                                              AppStore_Url  \
# 37955                                                 0.0
# 53838                                                 NaN
# 69783   https://apps.apple.com/us/app/le-us/developer/...
# 104915                                          https://a
# 114452                                                0.0
#
#                Primary_Genre        Content_Rating  Size_Bytes  \
# 37955                      0                   0.0         0.0
# 53838                    0.0                     0         0.0
# 69783                    NaN                   0.0         0.0
# 104915  2020-08-03T07:00:00Z  2020-08-03T14:14:33Z         1.0
# 114452                     0                   0.0         0.0
#
#        Required_IOS_Version Released Updated    Version         Price  \
# 37955                   NaN      NaN     NaN        NaN  10783.590774
# 53838                     0      NaN     NaN        NaN  10783.590774
# 69783                   0.0        0     NaN        NaN  10783.590774
# 104915                  0.0      USD    True  689053640  10783.590774
# 114452                  NaN      NaN     NaN        NaN  10783.590774
#
#                                                  Currency Free DeveloperId  \
# 37955                                                 NaN  NaN         NaN
# 53838                                                 NaN  NaN         NaN
# 69783                                                 NaN  NaN         NaN
# 104915  https://apps.apple.com/us/developer/the-univer...  NaN         0.0
# 114452                                                NaN  NaN         NaN
#
#        Developer Developer_Url  Average_User_Rating  Reviews  \
# 37955        NaN           NaN                  NaN      NaN
# 53838        NaN           NaN                  NaN      NaN
# 69783        NaN           NaN                  NaN      NaN
# 104915         0           0.0                  NaN      NaN
# 114452       NaN           NaN                  NaN      NaN
#
#         Current_Version_Score  Current_Version_Reviews
# 37955                     NaN                      NaN
# 53838                     NaN                      NaN
# 69783                     NaN                      NaN
# 104915                    NaN                      NaN
# 114452                    NaN                      NaN

# %%
df[df['Updated'].isnull()].head()
# Out:
#                                                    App_Id  \
# 37955                                               maxit
# 53838                                               maxit
# 69783                                 com.fideoo.legarden
# 114452  com/us/developer/zoho-corporation/id388384807?...
# 136632                                            ch.join
#
#                                                  App_Name  \
# 37955   Ability mLearning Plhttp://bibleall.com/Bhagav...
# 53838   Ability mLearning Plus/developer/oil-gas-uk/id...
# 69783                                           Le Garden
# 114452                    https://www.zoho.com/bugtracker
# 136632                                                NaN
#
#                                              AppStore_Url Primary_Genre  \
# 37955                                                 0.0             0
# 53838                                                 NaN           0.0
# 69783   https://apps.apple.com/us/app/le-us/developer/...           NaN
# 114452                                                0.0             0
# 136632                                                NaN           NaN
#
#        Content_Rating    Size_Bytes Required_IOS_Version Released Updated  \
# 37955             0.0  0.000000e+00                  NaN      NaN     NaN
# 53838               0  0.000000e+00                    0      NaN     NaN
# 69783             0.0  0.000000e+00                  0.0        0     NaN
# 114452            0.0  0.000000e+00                  NaN      NaN     NaN
# 136632            NaN  6.842015e+07                  NaN      NaN     NaN
#
#        Version         Price Currency Free DeveloperId Developer  \
# 37955      NaN  10783.590774      NaN  NaN         NaN       NaN
# 53838      NaN  10783.590774      NaN  NaN         NaN       NaN
# 69783      NaN  10783.590774      NaN  NaN         NaN       NaN
# 114452     NaN  10783.590774      NaN  NaN         NaN       NaN
# 136632     NaN  10783.590774      NaN  NaN         NaN       NaN
#
#        Developer_Url  Average_User_Rating  Reviews  Current_Version_Score  \
# 37955            NaN                  NaN      NaN                    NaN
# 53838            NaN                  NaN      NaN                    NaN
# 69783            NaN                  NaN      NaN                    NaN
# 114452           NaN                  NaN      NaN                    NaN
# 136632           NaN                  NaN      NaN                    NaN
#
#         Current_Version_Reviews
# 37955                       NaN
# 53838                       NaN
# 69783                       NaN
# 114452                      NaN
# 136632                      NaN

# %%
df[df['Currency'].isnull()].head()
# Out:
#                                                    App_Id  \
# 37955                                               maxit
# 53838                                               maxit
# 63390                           events.camarote.organizer
# 69783                                 com.fideoo.legarden
# 114452  com/us/developer/zoho-corporation/id388384807?...
#
#                                                  App_Name  \
# 37955   Ability mLearning Plhttp://bibleall.com/Bhagav...
# 53838   Ability mLearning Plus/developer/oil-gas-uk/id...
# 63390                              Camarote - Organizador
# 69783                                           Le Garden
# 114452                    https://www.zoho.com/bugtracker
#
#                                              AppStore_Url Primary_Genre  \
# 37955                                                 0.0             0
# 53838                                                 NaN           0.0
# 63390   https://apps.apple.com/us/app/camarote-organiz...      Business
# 69783   https://apps.apple.com/us/app/le-us/developer/...           NaN
# 114452                                                0.0             0
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 37955             0.0         0.0                  NaN                   NaN
# 53838               0         0.0                    0                   NaN
# 63390              4+  81971200.0                  9.0  2018-07-10T17:12:05Z
# 69783             0.0         0.0                  0.0                     0
# 114452            0.0         0.0                  NaN                   NaN
#
#        Updated    Version         Price Currency Free DeveloperId Developer  \
# 37955      NaN        NaN  10783.590774      NaN  NaN         NaN       NaN
# 53838      NaN        NaN  10783.590774      NaN  NaN         NaN       NaN
# 63390   201872  qinmin xu  10783.590774      NaN  0.0         0.0       0.0
# 69783      NaN        NaN  10783.590774      NaN  NaN         NaN       NaN
# 114452     NaN        NaN  10783.590774      NaN  NaN         NaN       NaN
#
#        Developer_Url  Average_User_Rating  Reviews  Current_Version_Score  \
# 37955            NaN                  NaN      NaN                    NaN
# 53838            NaN                  NaN      NaN                    NaN
# 63390              0                  NaN      NaN                    NaN
# 69783            NaN                  NaN      NaN                    NaN
# 114452           NaN                  NaN      NaN                    NaN
#
#         Current_Version_Reviews
# 37955                       NaN
# 53838                       NaN
# 63390                       NaN
# 69783                       NaN
# 114452                      NaN

# %% [markdown]
# ### Drop those rows where a column has null values

# %%
df.dropna(subset=['Current_Version_Reviews'], inplace=True)

df.dropna(subset=['Current_Version_Score'], inplace=True)

df.dropna(subset=['Reviews'], inplace=True)

df.dropna(subset=['Average_User_Rating'], inplace=True)

df.dropna(subset=['Developer'], inplace=True)

df.dropna(subset=['Developer_Url '], inplace=True)

df.dropna(subset=['DeveloperId'], inplace=True)

df.dropna(subset=['Updated '], inplace=True)

df.dropna(subset=['Version'], inplace=True)

df.dropna(subset=['Currency '], inplace=True)

df.dropna(subset=['Free '], inplace=True)

# %% [markdown]
# ### Have a view of refreshed dataset again

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Developer_Url              80
# App_Id                      0
# App_Name                    0
# Current_Version_Score       0
# Reviews                     0
# Average_User_Rating         0
# Developer                   0
# DeveloperId                 0
# Free                        0
# Currency                    0
# Price                       0
# Version                     0
# Updated                     0
# Released                    0
# Required_IOS_Version        0
# Size_Bytes                  0
# Content_Rating              0
# Primary_Genre               0
# AppStore_Url                0
# Current_Version_Reviews     0
# dtype: int64

# %% [markdown]
# # 7.  Find Duplications and Analyse them

# %% [markdown]
# ## Check Duplicates

# %%
df.duplicated().any()
# Out:
# True

# %%
any_duplicates = df.duplicated(subset=['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
       'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
       'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
       'Developer_Url', 'Average_User_Rating', 'Reviews',
       'Current_Version_Score', 'Current_Version_Reviews']).any()

# %%
boolean = df['App_Name'].duplicated().any()
boolean
# Out:
# True

# %% [markdown]
# ## Count repeating App Names

# %%
df['App_Name'].value_counts().sort_values(ascending=False)
# Out:
# Web2PDF                         4
# Audiostories                    4
# PageWyze                        4
# EditFire                        4
# FACTA                           4
#                                ..
# Neta Saiag - × ××¢ ×¡×××    1
# NETA.AVITAN.CPA                 1
# NetAcuity Truth                 1
# Netafim Payback Wizard          1
# Calculator â                  1
# Name: App_Name, Length: 76185, dtype: int64

# %% [markdown]
# ## Check App Name column which multiple rows are identical or not

# %%
df[df['App_Name'] == 'Web2PDF']
# Out:
#                                App_Id App_Name  \
# 93108   com.stahltechnologies.Web2PDF  Web2PDF
# 109068  com.stahltechnologies.Web2PDF  Web2PDF
# 118038          com.gkgkdrink.Web2Pdf  Web2PDF
# 133863          com.gkgkdrink.Web2Pdf  Web2PDF
#
#                                              AppStore_Url Primary_Genre  \
# 93108   https://apps.apple.com/us/app/web2pdf/id991606...     Utilities
# 109068  https://apps.apple.com/us/app/web2pdf/id991606...     Utilities
# 118038  https://apps.apple.com/us/app/web2pdf/id898644...  Productivity
# 133863  https://apps.apple.com/us/app/web2pdf/id898644...  Productivity
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 93108             17+    404065.0                 10.8  2015-05-12T10:00:10Z
# 109068            17+    404065.0                 10.8  2015-05-12T10:00:10Z
# 118038            17+  22107136.0                  9.0  2014-07-24T21:41:12Z
# 133863            17+  22107136.0                  9.0  2014-07-24T21:41:12Z
#
#                      Updated Version  Price Currency   Free  DeveloperId  \
# 93108   2015-05-12T10:00:10Z     1.0   1.99      USD  False    404884284
# 109068  2015-05-12T10:00:10Z     1.0   1.99      USD  False    404884284
# 118038  2017-05-12T18:31:28Z     2.0   0.00      USD   True  871691426.0
# 133863  2017-05-12T18:31:28Z     2.0   0.00      USD   True  871691426.0
#
#               Developer                                      Developer_Url  \
# 93108     Joacim StÃ¥hl  https://apps.apple.com/us/developer/joacim-st%...
# 109068    Joacim StÃ¥hl  https://apps.apple.com/us/developer/joacim-st%...
# 118038  KAZUNORI TANIJI  https://apps.apple.com/us/developer/kazunori-t...
# 133863  KAZUNORI TANIJI  https://apps.apple.com/us/developer/kazunori-t...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 93108                   0.0      0.0                    0.0
# 109068                  0.0      0.0                    0.0
# 118038                  0.0      0.0                    0.0
# 133863                  0.0      0.0                    0.0
#
#         Current_Version_Reviews
# 93108                       0.0
# 109068                      0.0
# 118038                      0.0
# 133863                      0.0

# %%
df[df['App_Name'] == 'Audiostories']
# Out:
#                          App_Id      App_Name  \
# 119562  audiostories.production  Audiostories
# 119563   com.kornick.audiotales  Audiostories
# 135387  audiostories.production  Audiostories
# 135388   com.kornick.audiotales  Audiostories
#
#                                              AppStore_Url Primary_Genre  \
# 119562  https://apps.apple.com/us/app/audiostories/id1...          Book
# 119563  https://apps.apple.com/us/app/audiostories/id1...         Music
# 135387  https://apps.apple.com/us/app/audiostories/id1...          Book
# 135388  https://apps.apple.com/us/app/audiostories/id1...         Music
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 119562             4+  69849088.0                 11.0  2021-08-03T07:00:00Z
# 119563            17+  20818944.0                 12.0  2021-02-24T08:00:00Z
# 135387             4+  69849088.0                 11.0  2021-08-03T07:00:00Z
# 135388            17+  20818944.0                 12.0  2021-02-24T08:00:00Z
#
#                      Updated Version  Price Currency  Free   DeveloperId  \
# 119562  2021-10-07T21:17:12Z   1.0.6    0.0      USD  True  1577945696.0
# 119563  2021-07-04T13:14:17Z  1.0.11    0.0      USD  True  1553970384.0
# 135387  2021-10-07T21:17:12Z   1.0.6    0.0      USD  True  1577945696.0
# 135388  2021-07-04T13:14:17Z  1.0.11    0.0      USD  True  1553970384.0
#
#                           Developer  \
# 119562  Audiostories Production LLC
# 119563                Mykola Koroid
# 135387  Audiostories Production LLC
# 135388                Mykola Koroid
#
#                                             Developer_Url  \
# 119562  https://apps.apple.com/us/developer/audiostori...
# 119563  https://apps.apple.com/us/developer/mykola-kor...
# 135387  https://apps.apple.com/us/developer/audiostori...
# 135388  https://apps.apple.com/us/developer/mykola-kor...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 119562                  0.0      0.0                    0.0
# 119563                  5.0      4.0                    5.0
# 135387                  0.0      0.0                    0.0
# 135388                  5.0      4.0                    5.0
#
#         Current_Version_Reviews
# 119562                      0.0
# 119563                      4.0
# 135387                      0.0
# 135388                      4.0

# %%
df[df['App_Name'] == 'PageWyze']
# Out:
#                   App_Id  App_Name  \
# 17000       com.PageWyze  PageWyze
# 32813       com.PageWyze  PageWyze
# 86998   com.pagewyze.mac  PageWyze
# 102966  com.pagewyze.mac  PageWyze
#
#                                              AppStore_Url Primary_Genre  \
# 17000   https://apps.apple.com/us/app/pagewyze/id14631...  Productivity
# 32813   https://apps.apple.com/us/app/pagewyze/id14631...  Productivity
# 86998   https://apps.apple.com/us/app/pagewyze/id14637...  Productivity
# 102966  https://apps.apple.com/us/app/pagewyze/id14637...  Productivity
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 17000              4+  15792128.0                 11.0  2019-08-07T03:59:34Z
# 32813              4+  15792128.0                 11.0  2019-08-07T03:59:34Z
# 86998              4+   5499472.0                10.13  2019-05-24T00:17:19Z
# 102966             4+   5499472.0                10.13  2019-05-24T00:17:19Z
#
#                      Updated Version  Price Currency  Free   DeveloperId  \
# 17000   2019-08-07T03:59:34Z  1.0.11    0.0      USD  True    1463192723
# 32813   2019-08-07T03:59:34Z  1.0.11    0.0      USD  True  1463192723.0
# 86998   2019-07-07T20:38:46Z   1.0.1    0.0      USD  True    1463192723
# 102966  2019-07-07T20:38:46Z   1.0.1    0.0      USD  True    1463192723
#
#         Developer                                      Developer_Url  \
# 17000   Nixel Inc  https://apps.apple.com/us/developer/nixel-inc/...
# 32813   Nixel Inc  https://apps.apple.com/us/developer/nixel-inc/...
# 86998   Nixel Inc  https://apps.apple.com/us/developer/nixel-inc/...
# 102966  Nixel Inc  https://apps.apple.com/us/developer/nixel-inc/...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 17000                   1.0      2.0                    1.0
# 32813                   1.0      2.0                    1.0
# 86998                   0.0      0.0                    0.0
# 102966                  0.0      0.0                    0.0
#
#         Current_Version_Reviews
# 17000                       2.0
# 32813                       2.0
# 86998                       0.0
# 102966                      0.0

# %%
df[df['App_Name'] == 'EditFire']
# Out:
#                         App_Id  App_Name  \
# 75337   com.crafx.editfire.mac  EditFire
# 91311   com.crafx.editfire.mac  EditFire
# 107546      com.crafx.editfire  EditFire
# 123438      com.crafx.editfire  EditFire
#
#                                              AppStore_Url    Primary_Genre  \
# 75337   https://apps.apple.com/us/app/editfire/id14473...  Developer Tools
# 91311   https://apps.apple.com/us/app/editfire/id14473...  Developer Tools
# 107546  https://apps.apple.com/us/app/editfire/id14473...         Business
# 123438  https://apps.apple.com/us/app/editfire/id14473...         Business
#
#        Content_Rating   Size_Bytes Required_IOS_Version              Released  \
# 75337              4+   61397613.0               10.9.0  2018-12-30T02:47:30Z
# 91311              4+   61397613.0               10.9.0  2018-12-30T02:47:30Z
# 107546             4+  242766848.0                  9.0  2018-12-23T04:24:19Z
# 123438             4+  242766848.0                  9.0  2018-12-23T04:24:19Z
#
#                      Updated Version  Price Currency   Free   DeveloperId  \
# 75337   2018-12-30T02:47:30Z     1.0   9.99      USD  False  1363888529.0
# 91311   2018-12-30T02:47:30Z     1.0   9.99      USD  False    1363888529
# 107546  2018-12-31T03:13:09Z   1.065   9.99      USD  False    1363888529
# 123438  2018-12-31T03:13:09Z   1.065   9.99      USD  False    1363888529
#
#        Developer                                      Developer_Url  \
# 75337      CRAFX  https://apps.apple.com/us/developer/crafx/id13...
# 91311      CRAFX  https://apps.apple.com/us/developer/crafx/id13...
# 107546     CRAFX  https://apps.apple.com/us/developer/crafx/id13...
# 123438     CRAFX  https://apps.apple.com/us/developer/crafx/id13...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 75337                   0.0      0.0                    0.0
# 91311                   0.0      0.0                    0.0
# 107546                  0.0      0.0                    0.0
# 123438                  0.0      0.0                    0.0
#
#         Current_Version_Reviews
# 75337                       0.0
# 91311                       0.0
# 107546                      0.0
# 123438                      0.0

# %%
df[df['App_Name'] == 'FACTA']
# Out:
#                      App_Id App_Name  \
# 5507      net.facta.eventos    FACTA
# 21309     net.facta.eventos    FACTA
# 107770  com.facta.prodestin    FACTA
# 123662  com.facta.prodestin    FACTA
#
#                                              AppStore_Url Primary_Genre  \
# 5507    https://apps.apple.com/us/app/facta/id14617223...      Business
# 21309   https://apps.apple.com/us/app/facta/id14617223...      Business
# 107770  https://apps.apple.com/us/app/facta/id14505421...  Productivity
# 123662  https://apps.apple.com/us/app/facta/id14505421...  Productivity
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 5507               4+  66995200.0                  9.0  2019-05-02T04:31:08Z
# 21309              4+  66995200.0                  9.0  2019-05-02T04:31:08Z
# 107770             4+  21660672.0                  9.0  2019-01-29T16:56:36Z
# 123662             4+  21660672.0                  9.0  2019-01-29T16:56:36Z
#
#                      Updated Version  Price Currency  Free DeveloperId  \
# 5507    2020-02-28T22:31:55Z     1.4    0.0      USD  True  1461722384
# 21309   2020-02-28T22:31:55Z     1.4    0.0      USD  True  1461722384
# 107770  2020-02-12T20:09:29Z     2.0    0.0      USD  True  1450542120
# 123662  2020-02-12T20:09:29Z     2.0    0.0      USD  True  1450542120
#
#                                                Developer  \
# 5507    FUNDACAO APINCO DE CIENCIA E TECNOLOGIA AVICOLAS
# 21309   FUNDACAO APINCO DE CIENCIA E TECNOLOGIA AVICOLAS
# 107770                                     Prodestin LLC
# 123662                                     Prodestin LLC
#
#                                             Developer_Url  \
# 5507    https://apps.apple.com/us/developer/fundacao-a...
# 21309   https://apps.apple.com/us/developer/fundacao-a...
# 107770  https://apps.apple.com/us/developer/prodestin-...
# 123662  https://apps.apple.com/us/developer/prodestin-...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 5507                    0.0      0.0                    0.0
# 21309                   0.0      0.0                    0.0
# 107770                  0.0      0.0                    0.0
# 123662                  0.0      0.0                    0.0
#
#         Current_Version_Reviews
# 5507                        0.0
# 21309                       0.0
# 107770                      0.0
# 123662                      0.0

# %%
df[df['App_Name'] == 'Calculator â']
# Out:
#                                     App_Id        App_Name  \
# 133485  com.incpt.mobis.CalculatorInfinite  Calculator â
#
#                                              AppStore_Url Primary_Genre  \
# 133485  https://apps.apple.com/us/app/calculator/id458...     Education
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 133485             4+  42279936.0                 12.1  2011-09-16T02:42:24Z
#
#                      Updated Version  Price Currency   Free  DeveloperId  \
# 133485  2021-09-25T10:06:58Z   5.8.1   4.99      USD  False  445261166.0
#
#           Developer                                      Developer_Url  \
# 133485  Incpt.Mobis  https://apps.apple.com/us/developer/incpt-mobi...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 133485              4.63145   3986.0                4.63145
#
#         Current_Version_Reviews
# 133485                   3986.0

# %% [markdown]
# ## Drop the rows that are Identical

# %%
rows_to_drop = [109068,133863,119563,135387,32813,86998,91311,107546,21309,107770]
df_dropped = df.drop(index=rows_to_drop)

# %%
# Drop rows in-place
df.drop(index=rows_to_drop, inplace=True)

# %% [markdown]
# # 8. Exploring Numeric columns

# %% [markdown]
# The unique() function returns an array containing the distinct values present in the specified column.

# %% [markdown]
# Each element in the array represents a unique size value found in the column.

# %%
df['Size_Bytes'].unique()
# Out:
# array([21993472., 13135872., 21943296., ...,  6253568., 44496896.,
#        20818944.])

# %%
df['Price'].unique()
# Out:
# array([0.00000000e+00, 2.99000000e+00, 1.99000000e+00, 9.90000000e-01,
#        4.99000000e+00, 9.99000000e+00, 5.99000000e+00, 6.99000000e+00,
#        1.69900000e+01, 1.99900000e+01, 3.99900000e+01, 5.99900000e+01,
#        8.99000000e+00, 7.99000000e+00, 1.89900000e+01, 3.99000000e+00,
#        2.49900000e+01, 1.49900000e+01, 2.89900000e+01, 2.19900000e+01,
#        1.39900000e+01, 1.09900000e+01, 1.19900000e+01, 1.29990000e+02,
#        2.29900000e+01, 1.39990000e+02, 2.59900000e+01, 1.29900000e+01,
#        4.99900000e+01, 2.39900000e+01, 1.19990000e+02, 7.99900000e+01,
#        1.79900000e+01, 4.99990000e+02, 2.49990000e+02, 2.99900000e+01,
#        4.09900000e+01, 3.49900000e+01, 1.74990000e+02, 5.49900000e+01,
#        1.49990000e+02, 2.29990000e+02, 9.49900000e+01, 1.99990000e+02,
#        2.09900000e+01, 9.99900000e+01, 3.39900000e+01, 4.59900000e+01,
#        4.49900000e+01, 6.99900000e+01, 2.79900000e+01, 8.49900000e+01,
#        6.49900000e+01, 1.59900000e+01, 7.49900000e+01, 3.59900000e+01,
#        3.49990000e+02, 2.69900000e+01, 4.89900000e+01, 1.09990000e+02,
#        3.89900000e+01, 3.19900000e+01, 3.69900000e+01, 8.99900000e+01,
#        1.69990000e+02, 1.24990000e+02, 1.07835908e+04, 3.99990000e+02,
#        2.19990000e+02, 4.39900000e+01, 6.99990000e+02, 4.29900000e+01,
#        3.79900000e+01, 2.99990000e+02, 4.49990000e+02, 1.59990000e+02,
#        4.19900000e+01, 3.29900000e+01, 3.09900000e+01, 7.99990000e+02])

# %%
df['Average_User_Rating'].unique()
# Out:
# array([0.     , 5.     , 4.78132, ..., 3.77922, 4.60822, 4.63145])

# %%
df['Reviews'].unique()
# Out:
# array([0.000e+00, 1.000e+00, 1.285e+03, ..., 4.065e+03, 1.635e+03,
#        5.526e+03])

# %%
df['Current_Version_Score'].unique()
# Out:
# array([0.     , 5.     , 4.78132, ..., 3.77922, 4.60822, 4.63145])

# %%
df['Currency'].unique()
# Out:
# array(['USD'], dtype=object)

# %%
df['Content_Rating'].unique()
# Out:
# array(['4+', '17+', '9+', '12+', 'Not yet rated'], dtype=object)

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# 1             4+  13135872.0                 10.0  2015-08-31T19:31:32Z
# 2             4+  21943296.0                  9.0  2021-04-14T07:00:00Z
# 3             4+  81851392.0                  8.0  2012-02-10T03:40:07Z
# 4             4+  64692224.0                  9.0  2020-12-16T08:00:00Z
#
#                 Updated Version  Price Currency   Free DeveloperId  \
# 0  2018-12-21T21:30:36Z   1.1.2   0.00      USD   True  1375410542
# 1  2019-07-23T20:31:09Z     1.3   0.00      USD   True  1031572001
# 2  2021-05-30T21:08:54Z   1.3.1   0.00      USD   True  1457024163
# 3  2019-10-29T12:40:37Z     1.2   2.99      USD  False   439568839
# 4  2020-12-18T21:36:11Z   1.0.1   0.00      USD   True   656731821
#
#         Developer                                      Developer_Url  \
# 0        HKBU ARC  https://apps.apple.com/us/developer/hkbu-arc/i...
# 1  Roman Dmitriev  https://apps.apple.com/us/developer/roman-dmit...
# 2         Terp AS  https://apps.apple.com/us/developer/terp-as/id...
# 3   i-editeur.com  https://apps.apple.com/us/developer/i-editeur-...
# 4   Ngov chiheang  https://apps.apple.com/us/developer/ngov-chihe...
#
#    Average_User_Rating  Reviews  Current_Version_Score  \
# 0                  0.0      0.0                    0.0
# 1                  5.0      1.0                    5.0
# 2                  0.0      0.0                    0.0
# 3                  0.0      0.0                    0.0
# 4                  0.0      0.0                    0.0
#
#    Current_Version_Reviews
# 0                      0.0
# 1                      1.0
# 2                      0.0
# 3                      0.0
# 4                      0.0

# %% [markdown]
# ## Adding column to hold Size_Bytes in MBs

# %% [markdown]
# creating Size_MB in dataframe

# %%
df['Size_MB'] = 0

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews', 'Size_MB'],
#       dtype='object')

# %% [markdown]
# Calculate Size in Megabytes (MB)

# %%
df['Size_MB'] = df['Size_Bytes'].apply(lambda x: (float(x) / 1024)/1024)

# %% [markdown]
# Descriptive Statistics for 'Average_User_Rating' column

# %%
df.Average_User_Rating.describe()
# Out:
# count    136603.000000
# mean          1.562618
# std           2.115996
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           4.000000
# max           5.000000
# Name: Average_User_Rating, dtype: float64

# %% [markdown]
# # 9. Creataing the column type for free and paid Apps

# %%
df['Type'] = np.where(df['Free'] == True,'Free','Paid')
df.drop(['Free'],axis=1, inplace= True )

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# 1             4+  13135872.0                 10.0  2015-08-31T19:31:32Z
# 2             4+  21943296.0                  9.0  2021-04-14T07:00:00Z
# 3             4+  81851392.0                  8.0  2012-02-10T03:40:07Z
# 4             4+  64692224.0                  9.0  2020-12-16T08:00:00Z
#
#                 Updated Version  Price Currency DeveloperId       Developer  \
# 0  2018-12-21T21:30:36Z   1.1.2   0.00      USD  1375410542        HKBU ARC
# 1  2019-07-23T20:31:09Z     1.3   0.00      USD  1031572001  Roman Dmitriev
# 2  2021-05-30T21:08:54Z   1.3.1   0.00      USD  1457024163         Terp AS
# 3  2019-10-29T12:40:37Z     1.2   2.99      USD   439568839   i-editeur.com
# 4  2020-12-18T21:36:11Z   1.0.1   0.00      USD   656731821   Ngov chiheang
#
#                                        Developer_Url  Average_User_Rating  \
# 0  https://apps.apple.com/us/developer/hkbu-arc/i...                  0.0
# 1  https://apps.apple.com/us/developer/roman-dmit...                  5.0
# 2  https://apps.apple.com/us/developer/terp-as/id...                  0.0
# 3  https://apps.apple.com/us/developer/i-editeur-...                  0.0
# 4  https://apps.apple.com/us/developer/ngov-chihe...                  0.0
#
#    Reviews  Current_Version_Score  Current_Version_Reviews    Size_MB  Type
# 0      0.0                    0.0                      0.0  20.974609  Free
# 1      1.0                    5.0                      1.0  12.527344  Free
# 2      0.0                    0.0                      0.0  20.926758  Free
# 3      0.0                    0.0                      0.0  78.059570  Paid
# 4      0.0                    0.0                      0.0  61.695312  Free

# %% [markdown]
# Descriptive Statistics for 'Reviews' Column

# %%
df.Reviews.describe()
# Out:
# count    1.366030e+05
# mean     5.638563e+02
# std      3.806841e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.000000e+00
# max      7.181127e+06
# Name: Reviews, dtype: float64

# %% [markdown]
# # 10. Viewing the content of the column 'Content_Rating'

# %% [markdown]
# First we will view the unique values present in this column

# %%
for i in df.Content_Rating.unique():
    print(i)
# Out:
# 4+
# 17+
# 9+
# 12+
# Not yet rated

# %% [markdown]
#     we have various Categories in the content Rating column :
#     4+
#     17+
#     9+
#     12+
#     Not yet rated
#     Now, we makes these categories to a simple 4 readable Categories for better understanding :
#     Children, Teens, Adults & Everyone
#
#     4+: Children
#     17+: Adults
#     9+: Children
#     12+: Teens
#     Not yet rated : Everyone

# %%
df["Content_Rating"]=df["Content_Rating"].replace("4+","Children")
df["Content_Rating"]=df["Content_Rating"].replace("9+","Children")
df["Content_Rating"]=df["Content_Rating"].replace("12+","Teens")
df["Content_Rating"]=df["Content_Rating"].replace("17+","Adults")
df["Content_Rating"]=df["Content_Rating"].replace("Not yet rated","Everyone")

# %% [markdown]
# Presenting the content of the coulumn in Ascending order 'Children', 'Teens', 'Everyone', 'Adults'

# %%
agegroup = df['Content_Rating'].unique()

# define the order in which you want to print the values
custom_order = ['Children', 'Teens', 'Everyone', 'Adults']

# sort the array in the custom order
sorted_array = sorted(['Children', 'Adults', 'Teens', 'Everyone'], key=lambda x: custom_order.index(x))

# print the sorted array
print(sorted_array)
# Out:
# ['Children', 'Teens', 'Everyone', 'Adults']

# %%
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0       Children  21993472.0                  8.0  2017-09-28T03:02:41Z
# 1       Children  13135872.0                 10.0  2015-08-31T19:31:32Z
# 2       Children  21943296.0                  9.0  2021-04-14T07:00:00Z
# 3       Children  81851392.0                  8.0  2012-02-10T03:40:07Z
# 4       Children  64692224.0                  9.0  2020-12-16T08:00:00Z
#
#                 Updated Version  Price Currency DeveloperId       Developer  \
# 0  2018-12-21T21:30:36Z   1.1.2   0.00      USD  1375410542        HKBU ARC
# 1  2019-07-23T20:31:09Z     1.3   0.00      USD  1031572001  Roman Dmitriev
# 2  2021-05-30T21:08:54Z   1.3.1   0.00      USD  1457024163         Terp AS
# 3  2019-10-29T12:40:37Z     1.2   2.99      USD   439568839   i-editeur.com
# 4  2020-12-18T21:36:11Z   1.0.1   0.00      USD   656731821   Ngov chiheang
#
#                                        Developer_Url  Average_User_Rating  \
# 0  https://apps.apple.com/us/developer/hkbu-arc/i...                  0.0
# 1  https://apps.apple.com/us/developer/roman-dmit...                  5.0
# 2  https://apps.apple.com/us/developer/terp-as/id...                  0.0
# 3  https://apps.apple.com/us/developer/i-editeur-...                  0.0
# 4  https://apps.apple.com/us/developer/ngov-chihe...                  0.0
#
#    Reviews  Current_Version_Score  Current_Version_Reviews    Size_MB  Type
# 0      0.0                    0.0                      0.0  20.974609  Free
# 1      1.0                    5.0                      1.0  12.527344  Free
# 2      0.0                    0.0                      0.0  20.926758  Free
# 3      0.0                    0.0                      0.0  78.059570  Paid
# 4      0.0                    0.0                      0.0  61.695312  Free

# %% [markdown]
# # 11. Grouping 'Reviews' into ranges for better data understanding

# %% [markdown]
# This step helps categorize individual review counts into specific ranges,
#  making it easier to observe patterns and trends in the data.

# %% [markdown]
# Check minimum Reviews

# %%
df.Reviews.min()
# Out:
# 0.0

# %% [markdown]
# Check maximum Reviews

# %%
df.Reviews.max()
# Out:
# 7181127.0

# %% [markdown]
# Statistical Description

# %%
df.Reviews.describe()
# Out:
# count    1.366030e+05
# mean     5.638563e+02
# std      3.806841e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.000000e+00
# max      7.181127e+06
# Name: Reviews, dtype: float64

# %% [markdown]
# Review column is numeric column that holds information about the number fo reviews users left while dowloading
# 1. if an app has reviews between 0 and 10000 --> Less than 10K
# 2. if an app has reviews between 10000 and 500000 --> Between 10K and 500K
# 3. if an app has reviews between 500000 and 1000000 --> Between 500K and 1Mil
# 4. if an app has reviews between 1000000 and 22685334 --> Million Plus

# %%
# Creating a new 'ReviewCategory' column and initializing it with 'NoReviewsProvided'
df['ReviewCategory'] = 'NoReviewsProvided'

# Categorizing reviews into specific ranges based on count
df.loc[(df['Reviews'] > 0) & (df['Reviews'] <= 10000.0),'ReviewCategory'] = 'Less than 10K'
df.loc[(df['Reviews'] > 10000) & (df['Reviews'] <= 500000.0),'ReviewCategory'] = 'Between 10K and 500K'
df.loc[(df['Reviews'] > 500000) & (df['Reviews'] <= 1000000),'ReviewCategory'] = 'Between 500K and 1Mil'
df.loc[(df['Reviews'] > 1000000) & (df['Reviews'] <= 22685334),'ReviewCategory'] = 'Million Plus'

# Counting the occurrences of each 'ReviewCategory'
df['ReviewCategory'].value_counts()
# Out:
# NoReviewsProvided        84117
# Less than 10K            52113
# Between 10K and 500K       347
# Million Plus                14
# Between 500K and 1Mil       12
# Name: ReviewCategory, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136603 entries, 0 to 136631
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   App_Id                   136603 non-null  object
#  1   App_Name                 136603 non-null  object
#  2   AppStore_Url             136603 non-null  object
#  3   Primary_Genre            136603 non-null  object
#  4   Content_Rating           136603 non-null  object
#  5   Size_Bytes               136603 non-null  float64
#  6   Required_IOS_Version     136603 non-null  object
#  7   Released                 136603 non-null  object
#  8   Updated                  136603 non-null  object
#  9   Version                  136603 non-null  object
#  10  Price                    136603 non-null  float64
#  11  Currency                 136603 non-null  object
#  12  DeveloperId              136603 non-null  object
#  13  Developer                136603 non-null  object
#  14  Developer_Url            136523 non-null  object
#  15  Average_User_Rating      136603 non-null  float64
#  16  Reviews                  136603 non-null  float64
#  17  Current_Version_Score    136603 non-null  float64
#  18  Current_Version_Reviews  136603 non-null  float64
#  19  Size_MB                  136603 non-null  float64
#  20  Type                     136603 non-null  object
#  21  ReviewCategory           136603 non-null  object
# dtypes: float64(7), object(15)
# memory usage: 24.0+ MB

# %% [markdown]
# We're cleaning up the 'Average_User_Rating' column. Currently, it has decimal values in the range of 0 to 5.

# %%
df["Average_User_Rating"] = df["Average_User_Rating"].round().astype(int)

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0       Children  21993472.0                  8.0  2017-09-28T03:02:41Z
# 1       Children  13135872.0                 10.0  2015-08-31T19:31:32Z
# 2       Children  21943296.0                  9.0  2021-04-14T07:00:00Z
# 3       Children  81851392.0                  8.0  2012-02-10T03:40:07Z
# 4       Children  64692224.0                  9.0  2020-12-16T08:00:00Z
#
#                 Updated Version  Price Currency DeveloperId       Developer  \
# 0  2018-12-21T21:30:36Z   1.1.2   0.00      USD  1375410542        HKBU ARC
# 1  2019-07-23T20:31:09Z     1.3   0.00      USD  1031572001  Roman Dmitriev
# 2  2021-05-30T21:08:54Z   1.3.1   0.00      USD  1457024163         Terp AS
# 3  2019-10-29T12:40:37Z     1.2   2.99      USD   439568839   i-editeur.com
# 4  2020-12-18T21:36:11Z   1.0.1   0.00      USD   656731821   Ngov chiheang
#
#                                        Developer_Url  Average_User_Rating  \
# 0  https://apps.apple.com/us/developer/hkbu-arc/i...                    0
# 1  https://apps.apple.com/us/developer/roman-dmit...                    5
# 2  https://apps.apple.com/us/developer/terp-as/id...                    0
# 3  https://apps.apple.com/us/developer/i-editeur-...                    0
# 4  https://apps.apple.com/us/developer/ngov-chihe...                    0
#
#    Reviews  Current_Version_Score  Current_Version_Reviews    Size_MB  Type  \
# 0      0.0                    0.0                      0.0  20.974609  Free
# 1      1.0                    5.0                      1.0  12.527344  Free
# 2      0.0                    0.0                      0.0  20.926758  Free
# 3      0.0                    0.0                      0.0  78.059570  Paid
# 4      0.0                    0.0                      0.0  61.695312  Free
#
#       ReviewCategory
# 0  NoReviewsProvided
# 1      Less than 10K
# 2  NoReviewsProvided
# 3  NoReviewsProvided
# 4  NoReviewsProvided

# %%
df.Average_User_Rating.unique()
# Out:
# array([0, 5, 3, 4, 2, 1])

# %% [markdown]
# # 12. Exploratory Analysis and Visualization

# %% [markdown]
# ## List the top 10 app categories from the Apple Store

# %%
top_Genre = df.Primary_Genre.value_counts().reset_index().rename(columns={'Primary_Genre':'Count','index':'Primary_Genre'})

# %%
top10_top_Genre = top_Genre.head(10)

# %%
top10_top_Genre.head(10)
# Out:
#      Primary_Genre  Count
# 0         Business  59807
# 1        Education  20780
# 2             Book  18553
# 3          Finance   5735
# 4     Productivity   5185
# 5        Utilities   4339
# 6  Developer Tools   3289
# 7        Reference   2722
# 8            Games   2509
# 9        Lifestyle   2288

# %%
sns.barplot(top10_top_Genre , x='Primary_Genre', y='Count', color='grey')
# Out:
# <Axes: xlabel='Primary_Genre', ylabel='Count'>

# %% [markdown]
# ## Top 10 Primary Genres with the Highest Average User Ratings

# %%
mean_ratings = df.groupby('Primary_Genre')['Average_User_Rating'].mean()


sorted_ratings = mean_ratings.sort_values(ascending=False)


top_10 = sorted_ratings.head(10)

print(top_10)
# Out:
# Primary_Genre
# Games            2.853727
# Stickers         2.693333
# Reference        2.637766
# Book             2.212850
# Weather          2.206897
# Music            2.144958
# Entertainment    2.094424
# Lifestyle        2.032343
# Finance          2.000523
# Photo & Video    1.770492
# Name: Average_User_Rating, dtype: float64

# %% [markdown]
# ## Identify the Primary_Genre with the highest count of both Paid and Free apps

# %%
# group the dataset by Primary_Genre and Type, and count the number of apps in each group
genre_counts = df.groupby(['Primary_Genre', 'Type']).size().reset_index(name='Count')
# # separate the free apps
top10_free_apps = genre_counts[genre_counts['Type'] == 'Free']
# ##load top 10 free apps
top_10_free_genres = top10_free_apps.sort_values(by='Count', ascending=False).head(10)

# top_10_free_genres

# # separate the free apps
top10_paid_apps = genre_counts[genre_counts['Type'] == 'Paid']
# ##load top 10 free apps
top_10_paid_genres = top10_paid_apps.sort_values(by='Count', ascending=False).head(10)

# %%
top_10_free_genres.head(5)
# Out:
#    Primary_Genre  Type  Count
# 2       Business  Free  23062
# 6      Education  Free   8607
# 0           Book  Free   7736
# 10       Finance  Free   2282
# 34  Productivity  Free   1767

# %%
top_10_paid_genres.head(5)
# Out:
#    Primary_Genre  Type  Count
# 3       Business  Paid  36745
# 7      Education  Paid  12173
# 1           Book  Paid  10817
# 11       Finance  Paid   3453
# 35  Productivity  Paid   3418

# %% [markdown]
# ## Top 5 Paid Apps based with highest ratings

# %%
top5_paid_apps = df[df['Type'] == 'Paid'].sort_values('Average_User_Rating', ascending=False).head(5)[['App_Name', 'Average_User_Rating']]


print(top5_paid_apps)
# Out:
#                               App_Name  Average_User_Rating
# 62947                  Vaquero Trading                    5
# 68879                          Barn360                    5
# 68866        Quick Resto Manager (old)                    5
# 22076    Glory ì±ê²½ -  ìí ë²ì                     5
# 68868  Quick Resume BuilderâCV Maker                    5

# %% [markdown]
# ##  Top 5 Free Apps with the Highest Ratings

# %%
# sort the paid apps by rating in descending order and select the top 5
top5_free_apps = df[df['Type'] == 'Free'].sort_values('Average_User_Rating', ascending=False).head(5)[['App_Name', 'Average_User_Rating']]

# display the top 5 paid apps and their ratings
print(top5_free_apps)
# Out:
#                                                App_Name  Average_User_Rating
# 38496                           Noorani Qaida (English)                    5
# 8990                                       Nepali Bible                    5
# 8981                                              Okubi                    5
# 8982                                             OkuOku                    5
# 131447  Easter Games Candy - match 3 for cute bunny hop                    5

# %% [markdown]
# ## Apps with highest content rating

# %%
lst_Content_Rating = df.Content_Rating.value_counts().reset_index().rename(columns={'Content_Rating':'Count','index':'Content_Rating'})
lst_Content_Rating.sort_values(by='Count', ascending=False)
# Out:
#   Content_Rating   Count
# 0       Children  118436
# 1         Adults   12781
# 2          Teens    5384
# 3       Everyone       2

# %% [markdown]
# ## Years with the Most App Releases

# %%
df['Released'] = pd.to_datetime(df['Released']) # convert to datetime format
df['Year_Release'] = df['Released'].dt.strftime('%Y')
cnt_year_app_Release = df.groupby(['Year_Release']).size().reset_index(name='Count')
cnt_year_app_Release.head(20).sort_values(by='Count', ascending=False)
# Out:
#    Year_Release  Count
# 12         2020  24900
# 13         2021  22652
# 11         2019  19295
# 10         2018  15100
# 9          2017  12628
# 8          2016  12439
# 7          2015   9334
# 6          2014   6981
# 5          2013   5098
# 4          2012   3577
# 3          2011   2651
# 2          2010   1414
# 1          2009    469
# 0          2008     63
# 14         2022      2

# %%
sns.barplot(cnt_year_app_Release , x='Year_Release', y='Count', color='grey')
# Out:
# <Axes: xlabel='Year_Release', ylabel='Count'>

# %% [markdown]
# ## Size in MBs vs. Price of App

# %%
# group the dataset by Primary_Genre and Type, and count the number of apps in each group
Tot_Apps_Size_Price = df.groupby(['Size_MB', 'Price']).size().reset_index(name='Count')

# ##load top 10 free apps
Top10_Apps_Size_Price = Tot_Apps_Size_Price.sort_values(by='Size_MB', ascending=False).head(10)
Top10_Apps_Size_Price
# Out:
#             Size_MB  Price  Count
# 59132  11819.127508   0.00      2
# 59131   7703.709580   4.99      2
# 59130   7467.170526   4.99      2
# 59129   7454.177939  24.99      1
# 59128   7054.005033   0.00      2
# 59127   6658.436141   6.99      2
# 59126   3735.692383   0.00      2
# 59125   3358.143555   4.99      2
# 59124   3236.703125   0.00      1
# 59123   3189.663086   2.99      1

# %% [markdown]
# Plot showing the size of the app in MB and its price

# %%
sns.barplot(Top10_Apps_Size_Price, x='Size_MB', y='Price', color='grey')
# Out:
# <Axes: xlabel='Size_MB', ylabel='Price'>

# %% [markdown]
# The pair-plot above further highlights the relation of Free and Paid app with the price

# %%
sns.pairplot(df, hue='Type', vars=['Size_MB', 'Price'])

# %% [markdown]
# ##  Top 10 App producing Developer

# %%
# group the dataset by Primary_Genre and Type, and count the number of apps in each group
Top10_Cnt_Dev = df.groupby(['Developer']).size().reset_index(name='Count')

# ##load top 10 free apps
Top10_Cnt_App_Dev = Top10_Cnt_Dev.sort_values(by='Count', ascending=False).head(10)

# %%
Top10_Cnt_App_Dev.head(10)
# Out:
#                           Developer  Count
# 29395        OOO Soft Save Serevice    351
# 29561              Oceanhouse Media    249
# 25070                        Mala M    225
# 3551              Arun Soundarrajan    225
# 17202                        Hoa Do    222
# 40183                 Tortoises Inc    218
# 45860         iGuru Portal Services    193
# 43230                Weetech Co Ltd    182
# 41360  Usatine & Erickson Media LLC    159
# 25469          Mario Guenther-Bruns    159

# %% [markdown]
# A pie chart showing which Developer or company has highest app development contribution to the app store

# %%
plt.figure(figsize=(8,6))
data = Top10_Cnt_App_Dev.groupby('Developer')['Count'].max().sort_values(ascending = True)
data = data.head(10)
labels = data.keys()
plt.pie(data, labels= labels,autopct='%.0f%%')
plt.title(" Top 10 App Producing developer", fontsize=14)
# Out:
# Text(0.5, 1.0, ' Top 10 App Producing developer')

# %% [markdown]
# ##  Genre-wise revenue analysis for different customer demographics

# %% [markdown]
#  Shows which genre attracted what kind of clintele in terms of revenues

# %%
df.groupby(['Primary_Genre', 'Content_Rating'])['Price'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Primary_Genre'>

# %%
# select the rows where Content_Rating is Toddlers and Primary_Genre is Business
toddler_business_df = df[(df['Content_Rating'] == 'Children') & (df['Primary_Genre'] == 'Business')]

# print the resulting DataFrame
toddler_business_df.head(5)
# Out:
#                                         App_Id  \
# 528  com.lettechnologies.Hadith-Collection-Pro
# 565                         com.thos.thoshukuk
# 569            tr.gov.tccb.mevzuatbilgisistemi
# 850                    tr.gov.tccb.resmigazete
# 885                   app.kickpro.ubonbookfair
#
#                                        App_Name  \
# 528                   Hadith Collection English
# 565                                       T-HOS
# 569                  T.C. Mevzuat Bilgi Sistemi
# 850                           T.C. Resmi Gazete
# 885  Ubon Book Fair à¸à¸£à¸±à¹à¸à¸à¸µà¹ 11
#
#                                           AppStore_Url Primary_Genre  \
# 528  https://apps.apple.com/us/app/hadith-collectio...      Business
# 565  https://apps.apple.com/us/app/t-hos/id13329939...      Business
# 569  https://apps.apple.com/us/app/t-c-mevzuat-bilg...      Business
# 850  https://apps.apple.com/us/app/t-c-resmi-gazete...      Business
# 885  https://apps.apple.com/us/app/ubon-book-fair-%...      Business
#
#     Content_Rating   Size_Bytes Required_IOS_Version  \
# 528       Children  443802624.0                 11.0
# 565       Children   20775936.0                 10.1
# 569       Children   12931072.0                 10.0
# 850       Children   15455232.0                 10.0
# 885       Children   55010304.0                 10.0
#
#                      Released               Updated Version  Price Currency  \
# 528 2021-01-15 08:00:00+00:00  2021-01-15T22:53:46Z     1.0   0.99      USD
# 565 2018-02-12 18:36:26+00:00  2021-09-17T10:05:06Z     1.9   0.00      USD
# 569 2019-11-22 08:00:00+00:00  2021-06-17T10:02:27Z   1.4.1   0.00      USD
# 850 2019-07-14 08:39:38+00:00  2021-07-01T18:40:48Z   2.2.3   0.00      USD
# 885 2019-08-05 07:00:00+00:00  2019-08-05T07:00:00Z     1.0   0.00      USD
#
#     DeveloperId                                          Developer  \
# 528  1097519044                                       Akhzar Nazir
# 565  1332993964  THOS HUKUK OTOMASYON SISTEMLERI YAZILIM ANONIM...
# 569   458584330          TÃ¼rkiye Cumhuriyeti CumhurbaÅkanlÄ±ÄÄ±
# 850   458584330          TÃ¼rkiye Cumhuriyeti CumhurbaÅkanlÄ±ÄÄ±
# 885   501928215                    Digital Insider Company Limited
#
#                                          Developer_Url  Average_User_Rating  \
# 528  https://apps.apple.com/us/developer/akhzar-naz...                    0
# 565  https://apps.apple.com/us/developer/thos-hukuk...                    0
# 569  https://apps.apple.com/us/developer/t%C3%BCrki...                    5
# 850  https://apps.apple.com/us/developer/t%C3%BCrki...                    3
# 885  https://apps.apple.com/us/developer/digital-in...                    0
#
#      Reviews  Current_Version_Score  Current_Version_Reviews     Size_MB  \
# 528      0.0                    0.0                      0.0  423.243164
# 565      0.0                    0.0                      0.0   19.813477
# 569      1.0                    5.0                      1.0   12.332031
# 850      2.0                    3.0                      2.0   14.739258
# 885      0.0                    0.0                      0.0   52.461914
#
#      Type     ReviewCategory Year_Release
# 528  Paid  NoReviewsProvided         2021
# 565  Free  NoReviewsProvided         2018
# 569  Free      Less than 10K         2019
# 850  Free      Less than 10K         2019
# 885  Free  NoReviewsProvided         2019

# %%
# select the rows where Content_Rating is Toddlers and Primary_Genre is Business
toddler_utility_df = df[(df['Content_Rating'] == 'Children') & (df['Primary_Genre'] == 'Utilities')]

# print the resulting DataFrame
toddler_utility_df.head(5)
# Out:
#                                App_Id                             App_Name  \
# 84                 com.lifeng.Dreader                             D-Reader
# 389  com.vrk.Universal.GanapatiStotra                      Ganapati Stotra
# 680          com.redstonz.noteslocker       Easy Notes Locker,Private Note
# 781                   tw.idv.sixlawna             S-linkå°ç£æ³å¾æ³è¦
# 782                     tw.idv.sixlaw  S-linkå°ç£æ³å¾æ³è¦(ç²¾ç°¡ç)
#
#                                           AppStore_Url Primary_Genre  \
# 84   https://apps.apple.com/us/app/d-reader/id10671...     Utilities
# 389  https://apps.apple.com/us/app/ganapati-stotra/...     Utilities
# 680  https://apps.apple.com/us/app/easy-notes-locke...     Utilities
# 781  https://apps.apple.com/us/app/s-link%E5%8F%B0%...     Utilities
# 782  https://apps.apple.com/us/app/s-link%E5%8F%B0%...     Utilities
#
#     Content_Rating   Size_Bytes Required_IOS_Version  \
# 84        Children   24834048.0                  7.0
# 389       Children   16099328.0                  8.0
# 680       Children    5597184.0                 13.0
# 781       Children  335846400.0                 12.0
# 782       Children  129798144.0                 12.0
#
#                      Released               Updated Version  Price Currency  \
# 84  2016-01-05 21:47:32+00:00  2016-03-26T14:17:30Z   1.0.3   0.00      USD
# 389 2013-06-21 01:22:45+00:00  2019-03-18T22:22:05Z     3.0   0.00      USD
# 680 2015-06-24 21:05:36+00:00  2021-06-10T07:31:14Z     1.5   0.00      USD
# 781 2018-02-03 05:24:44+00:00  2021-07-24T17:57:14Z  1.0.24  14.99      USD
# 782 2017-11-14 16:33:40+00:00  2021-07-24T20:32:25Z    1.27   0.00      USD
#
#     DeveloperId                                        Developer  \
# 84    592667658  Beijing Zhongxian Zhihui IP Consulting Co.,Ltd.
# 389   571853659                               Vaibhav Kavathekar
# 680   901183899                                      Waheed Khan
# 781  1311329204                                     ShuChi Huang
# 782  1311329204                                     ShuChi Huang
#
#                                          Developer_Url  Average_User_Rating  \
# 84   https://apps.apple.com/us/developer/beijing-zh...                    4
# 389  https://apps.apple.com/us/developer/vaibhav-ka...                    0
# 680  https://apps.apple.com/us/developer/waheed-kha...                    5
# 781  https://apps.apple.com/us/developer/shuchi-hua...                    0
# 782  https://apps.apple.com/us/developer/shuchi-hua...                    0
#
#      Reviews  Current_Version_Score  Current_Version_Reviews     Size_MB  \
# 84       1.0                    4.0                      1.0   23.683594
# 389      0.0                    0.0                      0.0   15.353516
# 680      1.0                    5.0                      1.0    5.337891
# 781      0.0                    0.0                      0.0  320.288086
# 782      0.0                    0.0                      0.0  123.785156
#
#      Type     ReviewCategory Year_Release
# 84   Free      Less than 10K         2016
# 389  Free  NoReviewsProvided         2013
# 680  Free      Less than 10K         2015
# 781  Paid  NoReviewsProvided         2018
# 782  Free  NoReviewsProvided         2017

# %% [markdown]
# ## Comparison of apps per Content_Rating

# %% [markdown]
# Year on Year engagement of various age groups as categorised by App Store

# %%
cnt_YoY = df.groupby(['Year_Release', 'Content_Rating', 'Primary_Genre']).size().reset_index(name='Count')
#cnt_year_app_Release.head(10).sort_values(by='Count', ascending=False)

cnt_YoY.groupby(['Year_Release', 'Content_Rating'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Year_Release'>

# %% [markdown]
# ##  User Rating vs Price

# %%
usr_Rat_Pri = df.groupby(['Average_User_Rating', 'Year_Release'])[['Price']].sum()


usr_Rat_Pri.groupby(['Year_Release', 'Average_User_Rating'])['Price'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Year_Release'>

# %% [markdown]
# ##  User Rating vs MBytes

# %%
usr_Rat_MB = df.groupby(['Average_User_Rating', 'Year_Release'])[['Size_MB']].sum()
# usr_Rat_Pri

usr_Rat_MB.groupby(['Year_Release', 'Average_User_Rating'])['Size_MB'].sum().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Year_Release'>

# %% [markdown]
# ## Top-5 Genre based on App Price

# %% [markdown]
# Year on Year break down of top-5 Genre based on App Price

# %%
Rev_per_Genre = df.groupby(['Year_Release','Primary_Genre' ])[['Price']].sum()


top5_genres = (Rev_per_Genre
                       .sort_values(['Year_Release', 'Price'], ascending=[True, False])
                       .groupby('Year_Release')
                       .head(5))

# Define a colormap: To present each category with a different color
cmap = plt.get_cmap('tab20')


# Group by year and primary genre, and plot a stacked bar chart
top5_genres.groupby(['Year_Release', 'Primary_Genre'])['Price'].sum().unstack().plot(kind='bar', stacked=True, title= "Year on Year break down of top-5 Genre based on App Price", cmap=cmap)

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Total Price')
plt.legend(title='Primary Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ##  IOS Versions Vs Count of app

# %%
# group the dataset by Primary_Genre and Type, and count the number of apps in each group
Ver_counts = df.groupby(['Required_IOS_Version']).size().reset_index(name='Count')



# ##load top 10 free apps
top_10_Ver_counts = Ver_counts.sort_values(by='Count', ascending=False).head(10)

sns.barplot(top_10_Ver_counts , x='Required_IOS_Version', y='Count', color='grey')
# Out:
# <Axes: xlabel='Required_IOS_Version', ylabel='Count'>

# %% [markdown]
# ## Interdependency of numeric attributes on each other

# %%
df.corr()
# Out:
# <ipython-input-100-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          Size_Bytes     Price  Average_User_Rating   Reviews  \
# Size_Bytes                 1.000000  0.009859             0.051629  0.012479
# Price                      0.009859  1.000000            -0.007444 -0.000249
# Average_User_Rating        0.051629 -0.007444             1.000000  0.023525
# Reviews                    0.012479 -0.000249             0.023525  1.000000
# Current_Version_Score      0.051687 -0.007463             0.998095  0.022482
# Current_Version_Reviews    0.012479 -0.000249             0.023525  1.000000
# Size_MB                    1.000000  0.009859             0.051629  0.012479
#
#                          Current_Version_Score  Current_Version_Reviews  \
# Size_Bytes                            0.051687                 0.012479
# Price                                -0.007463                -0.000249
# Average_User_Rating                   0.998095                 0.023525
# Reviews                               0.022482                 1.000000
# Current_Version_Score                 1.000000                 0.022482
# Current_Version_Reviews               0.022482                 1.000000
# Size_MB                               0.051687                 0.012479
#
#                           Size_MB
# Size_Bytes               1.000000
# Price                    0.009859
# Average_User_Rating      0.051629
# Reviews                  0.012479
# Current_Version_Score    0.051687
# Current_Version_Reviews  0.012479
# Size_MB                  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),cbar= True, cmap='coolwarm')
# Out:
# <ipython-input-101-20339db5f703>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar= True, cmap='coolwarm')
# <Axes: >

# %% [markdown]
# # 13. Save Data

# %%
# Saving the pre-processed Dataset
df.to_csv('clean_data.csv', index=False)

# %% [markdown]
# # THANK YOU
